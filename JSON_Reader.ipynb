# %%
import json

# %%
f = open("C:\\Users\\10007290\\AppData\\Roaming\\Gemini Studio\\Custom config.json")
# returns JSON object as 
# a dictionary
data = json.load(f)
  
# Iterating through the json
# list
#for i in data:
#    print(i)
print(json.dumps(data, indent=4))  
# Closing file
f.close()
# Out:
# {
#     "version": 1.1,
#     "doa_pull_source": 0,
#     "enable_statistics_doa": false,
#     "statistics_doa_threshold": 3,
#     "DOA_offset": 0,
#     "enable_flip_doa": false,
#     "beamforming_tolerance": 15,
#     "beamforming_lasting_ms": 1000,
#     "speaker_lasting_ms": 1500,
#     "Enable_system_tray": false,
#     "grid_compose_mode": true,
#     "group_compose_mode": false,
#     "focus_mode": true,
#     "body_fit_mode": true,
#     "audio_fit_mode": true,
#     "grid_mode": true,
#     "grid_mode_max_count": 4,
#     "grid_mode_roi_merge": true,
#     "presentation_mode": true,
#     "presentation_mode_presenter_size_level": 1,
#     "speaker_mode": true,
#     "single_speaker_mode": true,
#     "is_single_speaker_mode": false,
#     "topdown_mode": true,
#     "panorama_mode": false,
#     "default_display_mode": 0,
#     "display_modes_per_row": 3,
#     "update_link": [
#         {
#             "name": "default",
#             "link": "https://studio.cupola360.com/"
#         }
#     ],
#     "detect_interval": 500,
#     "default_auto_detect": false,
#     "detect_conf_threshold": 0.6,
#     "detect_overlap_ratio": 0.2,
#     "detect_remove_threshold": 4,
#     "stable_roi_min": 20,
#     "stable_roi_max": 50,
#     "min_rect_side_length": 320,
#     "max_detect_rect_side_length": 800,
#     "face_enlarge_ratio": 1.4,
#     "auto_fit_rect_width_pixels": 250,
#     "fov1_value": 256,
#     "fov2_value": 0,
#     "fov3_value": -256,
#     "max_stretch_ratio": 1.5,
#     "video_pan_weight": 0.1,
#     "transition_frame_count": 10,
#     "camera_name": [
#         "Cupola360 Camera",
#         "SC25 Camera",
#         "USB Camera",
#         "AOPEN KP180 Camera",
#         "O-Meet 360 Camera",
#         "SanJet 360 Camera",
#         "OMMAGIC VC101",
#         "OMMAGIC VC100",
#         "UNITE 180",
#         "MAXHUB MD10A",
#         "OMMAGIC VP1000",
#         "OMMAGIC VP200",
#         "Innex C830 Camera"
#     ],
#     "camera_pid": [
#         "0x0504",
#         "0x0506",
#         "0x1230",
#         "0x1221",
#         "0x1220",
#         "0x003d",
#         "0x5002",
#         "0x5000",
#         "0x5006",
#         "0x0003"
#     ],
#     "camera_vid": [
#         "0x1ff7",
#         "0x1ff7",
#         "0x2245",
#         "0x2245",
#         "0x2245",
#         "0x146e",
#         "0x2e8b",
#         "0x2e8b",
#         "0x2e8b",
#         "0x3429"
#     ],
#     "default_track_type": 2,
#     "default_simple_ui": false,
#     "connect_retry_time": 20,
#     "enable_button_tips": true,
#     "default_large_navigator": true,
#     "always_do_transition_in_speaker_mode": false,
#     "min_src_height_scale": 1.0,
#     "disable_auto_flicker": false,
#     "enable_new_detect_layout": true,
#     "enable_tutorial": true,
#     "manual_focus_rect": [],
#     "present_rect": [],
#     "roi_record1": [
#         {
#             "x1": 0.3037,
#             "y1": 0.06666,
#             "x2": 0.45185,
#             "y2": 0.06666,
#             "x3": 0.45185,
#             "y3": 0.95555,
#             "x4": 0.3037,
#             "y4": 0.95555
#         },
#         {
#             "x1": 0.54814,
#             "y1": 0.06666,
#             "x2": 0.6963,
#             "y2": 0.06666,
#             "x3": 0.6963,
#             "y3": 0.95555,
#             "x4": 0.54814,
#             "y4": 0.95555
#         }
#     ],
#     "roi_record1_base_pos": 0.0,
#     "roi_record1_fov": 2,
#     "roi_record1_mirror": false,
#     "roi_record1_180_crop_y": 0.5,
#     "roi_record2": [
#         {
#             "x1": 0.1815,
#             "y1": 0.06666,
#             "x2": 0.33,
#             "y2": 0.06666,
#             "x3": 0.33,
#             "y3": 0.95555,
#             "x4": 0.1815,
#             "y4": 0.95555
#         },
#         {
#             "x1": 0.426,
#             "y1": 0.06666,
#             "x2": 0.574,
#             "y2": 0.06666,
#             "x3": 0.574,
#             "y3": 0.95555,
#             "x4": 0.426,
#             "y4": 0.95555
#         },
#         {
#             "x1": 0.67,
#             "y1": 0.06666,
#             "x2": 0.8185,
#             "y2": 0.06666,
#             "x3": 0.8185,
#             "y3": 0.95555,
#             "x4": 0.67,
#             "y4": 0.95555
#         }
#     ],
#     "roi_record2_base_pos": 0.0,
#     "roi_record2_fov": 2,
#     "roi_record2_mirror": false,
#     "roi_record2_180_crop_y": 0.5,
#     "roi_record3": [
#         {
#             "x1": 0.5444,
#             "y1": 0.06666,
#             "x2": 0.6926,
#             "y2": 0.06666,
#             "x3": 0.6926,
#             "y3": 0.95555,
#             "x4": 0.5444,
#             "y4": 0.95555
#         },
#         {
#             "x1": 0.0555,
#             "y1": 0.06666,
#             "x2": 0.2037,
#             "y2": 0.06666,
#             "x3": 0.2037,
#             "y3": 0.95555,
#             "x4": 0.0555,
#             "y4": 0.95555
#         },
#         {
#             "x1": 0.3,
#             "y1": 0.06666,
#             "x2": 0.4481,
#             "y2": 0.06666,
#             "x3": 0.4481,
#             "y3": 0.95555,
#             "x4": 0.3,
#             "y4": 0.95555
#         },
#         {
#             "x1": 0.7888,
#             "y1": 0.06666,
#             "x2": 0.937,
#             "y2": 0.06666,
#             "x3": 0.937,
#             "y3": 0.95555,
#             "x4": 0.7888,
#             "y4": 0.95555
#         }
#     ],
#     "roi_record3_base_pos": 0.0,
#     "roi_record3_fov": 2,
#     "roi_record3_mirror": false,
#     "roi_record3_180_crop_y": 0.5,
#     "roi_record_index": 0,
#     "enable_launch_detect": true,
#     "enable_perspective_projection": true,
#     "show_issue_report": true
# }

# %%
f = open("C:\\Users\\10007290\\AppData\\Roaming\\Gemini Studio\\Custom config.json")
# returns JSON object as 
# a dictionary
data = json.load(f)
  
# Iterating through the json
# list
#for i in data:
#    print(i)
print(json.dumps(data, indent=4))  
# Closing file
f.close()
# Out:
# {
#     "version": 1.1,
#     "doa_pull_source": 0,
#     "enable_statistics_doa": false,
#     "statistics_doa_threshold": 3,
#     "DOA_offset": 0,
#     "enable_flip_doa": false,
#     "beamforming_tolerance": 15,
#     "beamforming_lasting_ms": 1000,
#     "speaker_lasting_ms": 1500,
#     "Enable_system_tray": false,
#     "grid_compose_mode": true,
#     "group_compose_mode": false,
#     "focus_mode": true,
#     "body_fit_mode": true,
#     "audio_fit_mode": true,
#     "grid_mode": true,
#     "grid_mode_max_count": 4,
#     "grid_mode_roi_merge": true,
#     "presentation_mode": true,
#     "presentation_mode_presenter_size_level": 1,
#     "speaker_mode": true,
#     "single_speaker_mode": false,
#     "is_single_speaker_mode": false,
#     "topdown_mode": true,
#     "panorama_mode": false,
#     "default_display_mode": 0,
#     "display_modes_per_row": 3,
#     "update_link": [
#         {
#             "name": "default",
#             "link": "https://studio.cupola360.com/"
#         }
#     ],
#     "detect_interval": 500,
#     "default_auto_detect": true,
#     "detect_conf_threshold": 0.6,
#     "detect_overlap_ratio": 0.2,
#     "detect_remove_threshold": 4,
#     "stable_roi_min": 20,
#     "stable_roi_max": 50,
#     "min_rect_side_length": 320,
#     "max_detect_rect_side_length": 800,
#     "face_enlarge_ratio": 1.4,
#     "auto_fit_rect_width_pixels": 250,
#     "fov1_value": 256,
#     "fov2_value": 0,
#     "fov3_value": -256,
#     "max_stretch_ratio": 1.5,
#     "video_pan_weight": 0.1,
#     "transition_frame_count": 10,
#     "camera_name": [
#         "Cupola360 Camera",
#         "SC25 Camera",
#         "USB Camera",
#         "AOPEN KP180 Camera",
#         "O-Meet 360 Camera",
#         "SanJet 360 Camera",
#         "OMMAGIC VC101",
#         "OMMAGIC VC100",
#         "UNITE 180",
#         "MD10A",
#         "OMMAGIC VP1000",
#         "OMMAGIC VP200",
#         "Innex C830 Camera",
#         "TEVO-CC600",
#         "Venus C001",
#         "JS VC1000 Video",
#         "OMMAGIC VP300",
#         "UC M40",
#         "SC360"
#     ],
#     "camera_pid": [
#         "0x0504",
#         "0x0506",
#         "0x1230",
#         "0x1221",
#         "0x1220",
#         "0x003d",
#         "0x5002",
#         "0x5000",
#         "0x5006",
#         "0x5012",
#         "0x5014",
#         "0x0003",
#         "0x4001"
#     ],
#     "camera_vid": [
#         "0x1ff7",
#         "0x1ff7",
#         "0x2245",
#         "0x2245",
#         "0x2245",
#         "0x146e",
#         "0x2e8b",
#         "0x2e8b",
#         "0x2e8b",
#         "0x2e8b",
#         "0x2e8b",
#         "0x3429",
#         "0x0601"
#     ],
#     "default_track_type": 2,
#     "default_simple_ui": false,
#     "connect_retry_time": 20,
#     "enable_button_tips": true,
#     "default_large_navigator": false,
#     "always_do_transition_in_speaker_mode": false,
#     "min_src_height_scale": 1.0,
#     "disable_auto_flicker": false,
#     "enable_new_detect_layout": true,
#     "enable_tutorial": true,
#     "manual_focus_rect": [
#         {
#             "x1": 0.35,
#             "y1": 0.2,
#             "x2": 0.7,
#             "y2": 0.2,
#             "x3": 0.7,
#             "y3": 0.8,
#             "x4": 0.35,
#             "y4": 0.8
#         }
#     ],
#     "present_rect": [
#         {
#             "x1": 0.35,
#             "y1": 0.2,
#             "x2": 0.7,
#             "y2": 0.2,
#             "x3": 0.7,
#             "y3": 0.8,
#             "x4": 0.35,
#             "y4": 0.8
#         }
#     ],
#     "roi_record1": [
#         {
#             "x1": 0.3037,
#             "y1": 0.06666,
#             "x2": 0.45185,
#             "y2": 0.06666,
#             "x3": 0.45185,
#             "y3": 0.95555,
#             "x4": 0.3037,
#             "y4": 0.95555
#         },
#         {
#             "x1": 0.54814,
#             "y1": 0.06666,
#             "x2": 0.6963,
#             "y2": 0.06666,
#             "x3": 0.6963,
#             "y3": 0.95555,
#             "x4": 0.54814,
#             "y4": 0.95555
#         }
#     ],
#     "roi_record1_base_pos": 0.0,
#     "roi_record1_fov": 2,
#     "roi_record1_mirror": false,
#     "roi_record1_180_crop_y": 0.5,
#     "roi_record2": [
#         {
#             "x1": 0.1815,
#             "y1": 0.06666,
#             "x2": 0.33,
#             "y2": 0.06666,
#             "x3": 0.33,
#             "y3": 0.95555,
#             "x4": 0.1815,
#             "y4": 0.95555
#         },
#         {
#             "x1": 0.426,
#             "y1": 0.06666,
#             "x2": 0.574,
#             "y2": 0.06666,
#             "x3": 0.574,
#             "y3": 0.95555,
#             "x4": 0.426,
#             "y4": 0.95555
#         },
#         {
#             "x1": 0.67,
#             "y1": 0.06666,
#             "x2": 0.8185,
#             "y2": 0.06666,
#             "x3": 0.8185,
#             "y3": 0.95555,
#             "x4": 0.67,
#             "y4": 0.95555
#         }
#     ],
#     "roi_record2_base_pos": 0.0,
#     "roi_record2_fov": 2,
#     "roi_record2_mirror": false,
#     "roi_record2_180_crop_y": 0.5,
#     "roi_record3": [
#         {
#             "x1": 0.5444,
#             "y1": 0.06666,
#             "x2": 0.6926,
#             "y2": 0.06666,
#             "x3": 0.6926,
#             "y3": 0.95555,
#             "x4": 0.5444,
#             "y4": 0.95555
#         },
#         {
#             "x1": 0.0555,
#             "y1": 0.06666,
#             "x2": 0.2037,
#             "y2": 0.06666,
#             "x3": 0.2037,
#             "y3": 0.95555,
#             "x4": 0.0555,
#             "y4": 0.95555
#         },
#         {
#             "x1": 0.3,
#             "y1": 0.06666,
#             "x2": 0.4481,
#             "y2": 0.06666,
#             "x3": 0.4481,
#             "y3": 0.95555,
#             "x4": 0.3,
#             "y4": 0.95555
#         },
#         {
#             "x1": 0.7888,
#             "y1": 0.06666,
#             "x2": 0.937,
#             "y2": 0.06666,
#             "x3": 0.937,
#             "y3": 0.95555,
#             "x4": 0.7888,
#             "y4": 0.95555
#         }
#     ],
#     "roi_record3_base_pos": 0.0,
#     "roi_record3_fov": 2,
#     "roi_record3_mirror": false,
#     "roi_record3_180_crop_y": 0.5,
#     "roi_record_index": 0,
#     "enable_launch_detect": true,
#     "enable_perspective_projection": true,
#     "show_issue_report": true
# }
